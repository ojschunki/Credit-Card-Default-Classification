# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data and Preprocessing

# %%
# !pip install ucimlrepo

from IPython.display import clear_output
clear_output()

# %%
from ucimlrepo import fetch_ucirepo

df = fetch_ucirepo(id=0) # TODO replace 0 with uci id
